# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/floating-bottle-detection-v3/README.dataset.txt
# /kaggle/input/floating-bottle-detection-v3/README.roboflow.txt
# /kaggle/input/floating-bottle-detection-v3/data.yaml
# /kaggle/input/floating-bottle-detection-v3/valid/labels/bottle-656-_JPG_jpg.rf.d9f33cc4c515500745beb5c6fee14363.txt
# /kaggle/input/floating-bottle-detection-v3/valid/labels/000998_jpg.rf.6aab59d4ffcd0b1e4df160cb1ff39374.txt
# /kaggle/input/floating-bottle-detection-v3/valid/labels/001007_jpg.rf.a1bd73d37e092540ef623bf86a09ff79.txt
# /kaggle/input/floating-bottle-detection-v3/valid/labels/0218091924_jpg.rf.ea86336f898b0638e72e3ea827423ec0.txt
# /kaggle/input/floating-bottle-detection-v3/valid/labels/bottle-9-_JPG_jpg.rf.41f956435ed2b4c1c8841d11f3e53ce3.txt
# /kaggle/input/floating-bottle-detection-v3/valid/labels/bottle-94-_JPG_jpg.rf.8f1c6ef96a74d00d72781997d0d810d3.txt
# /kaggle/input/floating-bottle-detection-v3/valid/labels/bottle-790-_jpg.rf.da273d3c038eaa6fb0bd519777d990ce.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 27.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00:00:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 47.2 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

# Print model hyperparameters
print("-----------------------------Model hyperparameters----------------------------")
print(model.args)

# Model training
print("\n--------------------------------Model training--------------------------------")

model.train(
    data='/kaggle/input/floating-bottle-detection-v3/data.yaml',
    epochs=80,
    imgsz=640,
    batch=32,
    name='yolov8n_v3.6',
    device=[0,1]
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 80.5MB/s]
# -----------------------------Model hyperparameters----------------------------
# {'task': 'detect', 'data': 'coco.yaml', 'imgsz': 640, 'single_cls': False, 'model': 'yolov8n.pt'}
#
# --------------------------------Model training--------------------------------
# Ultralytics 8.3.167 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                         CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# import shutil
# from IPython.display import FileLink

# # Zip output files
# shutil.make_archive('/kaggle/working/output_runs', 'zip', '/kaggle/working/runs')

# # Create a clickable download link
# FileLink(r'/kaggle/working/output_runs.zip')

# Zips only the /kaggle/working/runs directory and provides download link

import os
import zipfile
from IPython.display import FileLink, display

def zip_and_download_runs():
    source_dir = '/kaggle/working/runs'
    zip_name = 'runs_output.zip'
    
    if not os.path.exists(source_dir):
        print(f"Error: Directory {source_dir} not found!")
        return
        
    # Create zip file
    with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(source_dir):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, start='/kaggle/working')
                zipf.write(file_path, arcname)
                print(f"Added: {arcname}")
    
    # Verify zip was created
    if os.path.exists(zip_name):
        print(f"\nSuccess! Zip file created: {os.path.getsize(zip_name)/1024/1024:.2f} MB")
        print("Download link:")
        display(FileLink(zip_name))
    else:
        print("Failed to create zip file")

# Execute
zip_and_download_runs()
# Out:
# Added: runs/detect/yolov8n_v3.6/train_batch0.jpg
# Added: runs/detect/yolov8n_v3.6/BoxF1_curve.png
# Added: runs/detect/yolov8n_v3.6/train_batch2.jpg
# Added: runs/detect/yolov8n_v3.6/train_batch15192.jpg
# Added: runs/detect/yolov8n_v3.6/results.png
# Added: runs/detect/yolov8n_v3.6/train_batch15191.jpg
# Added: runs/detect/yolov8n_v3.6/confusion_matrix_normalized.png
# Added: runs/detect/yolov8n_v3.6/val_batch0_labels.jpg
# Added: runs/detect/yolov8n_v3.6/train_batch15190.jpg
# Added: runs/detect/yolov8n_v3.6/confusion_matrix.png
# Added: runs/detect/yolov8n_v3.6/args.yaml
# Added: runs/detect/yolov8n_v3.6/labels.jpg
# Added: runs/detect/yolov8n_v3.6/BoxR_curve.png
# Added: runs/detect/yolov8n_v3.6/val_batch1_pred.jpg
# Added: runs/detect/yolov8n_v3.6/val_batch0_pred.jpg
# Added: runs/detect/yolov8n_v3.6/train_batch1.jpg
# Added: runs/detect/yolov8n_v3.6/val_batch2_labels.jpg
# Added: runs/detect/yolov8n_v3.6/results.csv
# Added: runs/detect/yolov8n_v3.6/val_batch1_labels.jpg
# ...
